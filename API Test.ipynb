# %%
import datetime as dt
import json
import requests as rq
import pandas as pd
import numpy as np
import bybitopt as bbp

# %%
desk = bbp.get_option_desk(True)
# Out:
# Processing time: 137.35604214668274

# %%
desk['C28OCT22']['bid'][desk['C28OCT22']['bid'] != 0].plot(figsize=(15,8),style='o-')
desk['C28OCT22']['ask'][desk['C28OCT22']['ask'] != 0].plot(figsize=(15,8),style='o-')
# Out:
# <AxesSubplot:xlabel='strike'>
